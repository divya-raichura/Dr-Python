# %%
class Human:
    age = 10
    def fun():
        print("Hello World")

# %%
kunal = Human()

# %%
kunal.fun()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 kunal.fun()
#
# TypeError: Human.fun() takes 0 positional arguments but 1 was given

# %%
class Human:
    age = 10
    def fun(something):  # this something is 'self', it means object/ref var name 
        print(something)  
        print("Hello World")

# %%
apoorv = Human()

# %%
apoorv.fun()
# Out:
# <__main__.Human object at 0x0000021F0749A950>
# Hello World

# %%
class Human:
    age = 10
    def fun(self):  # wherever we write self, it is replaced by  object/ref var name 
        print(self)  
        print(age)

# %%
elon = Human()

# %%
elon.fun()
# Out:
# <__main__.Human object at 0x0000023D97164850>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 elon.fun()
#
# Input In [4], in Human.fun(self)
#       3 def fun(self):  # wherever we write self, it is replaced by  object/ref var name
#       4     print(self)
# ----> 5     print(age)
#
# NameError: name 'age' is not defined

# %%
class Human:
    age = 10
    def fun(self):  # wherever we write self, it is replaced by  object/ref var name 
        print(self.age)

# %%
vedika = Human()

# %%
vedika.fun()  # object doesn't have age so it prints default one
# it goes inside fun and does print(vedika.age)
# vedika has age? no so class has? yes, print it then
# Out:
# 10

# %%
raichura = Human()

# %%
raichura.age = 100

# %%
raichura.fun()  # this time, obj has age, so it will not print default, it will print age of obj
# Out:
# 100

# %%
# class Human:
#     age = 10
#     def fun(self):  
#         print(self.age) # we can do, Human.age, for this it will print default age
# for every object

# %%
raichura.fun()
# this is same as below:-
# Out:
# 100

# %%
Human.fun(raichura)
# Out:
# 100

# %%
class Human:
    age = 10
    def fun(self):  # wherever we write self, it is replaced by  object/ref var name 
        print(musk.age)

# %%
musk = Human()

# %%
musk.fun()
# Out:
# 10

# %%
mom = Human()

# %%
mom.fun()
# Out:
# 10

# %%
mom.age = 50

# %%
mom.fun()
# Out:
# 10
